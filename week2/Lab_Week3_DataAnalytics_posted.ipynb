# %%
import os
os.chdir('???')
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-94d77baee8d6> in <module>
#       1 import os
# ----> 2 os.chdir('???')
#       3 os.getcwd()
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: '???'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df5 = pd.read_csv('education_expense_2015_2016.csv',sep=',',header='infer')
df5.head()
# Out:
#   CountryName                 Region  ThirdWorld  Primary2015  Primary2016  \
# 0     Albania         Eastern Europe           0    105.54300     105.5539
# 1   Argentina          South America           0    111.30340     110.7392
# 2     Armenia           Western Asia           0     95.00365      94.5179
# 3   Australia  Australia and Oceanea           0    101.59990     100.7444
# 4     Austria         Western Europe           0    101.99750     102.2644
#
#    EduExpense2015  EduExpense2016
# 0         3.43797         3.95464
# 1         5.77611         5.57218
# 2         2.80591         2.75812
# 3         5.32175         5.28031
# 4         5.45675         5.50070

# %%
sns.heatmap(df5.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df5.describe()
# Out:
#        ThirdWorld  Primary2015  Primary2016  EduExpense2015  EduExpense2016
# count   74.000000    74.000000    74.000000       74.000000       74.000000
# mean     0.175676   104.754530   104.927552        4.865514        4.867802
# std      0.383142    12.619306    12.277786        1.322263        1.289451
# min      0.000000    71.595910    73.432330        2.228750        2.558820
# 25%      0.000000    99.911680    99.930733        3.958565        3.878100
# 50%      0.000000   102.043400   102.557050        4.880185        4.928300
# 75%      0.000000   106.542125   106.255400        5.609208        5.497267
# max      1.000000   146.396800   144.532900        7.552470        7.976100

# %%
df5.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000197921BD320>,
# ...
#       dtype=object)

# %%
df5.hist(column='EduExpense2016')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001979243B828>]],
#       dtype=object)

# %%
sns.distplot(df5['EduExpense2016'], hist=True, kde=False, rug=False)

# %%
sns.distplot(df5['EduExpense2016'], hist=True, kde=True, rug=False)

# %%
sns.distplot(df5['EduExpense2016'], hist=False, kde=True, rug=True)

# %%
df5.Region.unique()
# Out:
# array(['Eastern Europe', 'South America', 'Western Asia',
#        'Australia and Oceanea', 'Western Europe', 'North America',
#        'Africa', 'South Asia', 'Northern Europe', 'East Asia',
#        'Middle East', 'Southeast Asia'], dtype=object)

# %%
df5[df5.Region=='Africa']
# Out:
#               CountryName  Region  ThirdWorld  Primary2015  Primary2016  \
# 9                   Benin  Africa           1    132.46680    130.90230
# 11                Burundi  Africa           1    130.90340    128.04210
# 12             Cabo Verde  Africa           0    105.49680    103.90750
# 13               Cameroon  Africa           0    116.21040    116.11730
# 17          Cote d'Ivoire  Africa           0     90.65904     95.88669
# 24                  Ghana  Africa           0    108.33790    106.72800
# 36                  Kenya  Africa           0    103.66160    103.20530
# 41                 Malawi  Africa           1    146.39680    144.53290
# 44                   Mali  Africa           1     75.68318     77.17026
# 45              Mauritius  Africa           0    102.92050    102.45340
# 51                  Niger  Africa           1     71.59591     73.43233
# 56                 Rwanda  Africa           1    139.62440    141.27870
# ...

# %%
df5[df5.Region=='Africa'].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000197925F7EB8>,
# ...
#       dtype=object)

# %%
df5[df5.Region=='North America'].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000197928392B0>,
# ...
#       dtype=object)

# %%
sns.boxplot(x='EduExpense2016', data=df5)

# %%
sns.boxplot(x='Region',y='EduExpense2016', data=df5)

# %%
chart = sns.boxplot(x='Region',y='EduExpense2016', data=df5)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Eastern Europe'),
#  Text(0, 0, 'South America'),
#  Text(0, 0, 'Western Asia'),
#  Text(0, 0, 'Australia and Oceanea'),
#  Text(0, 0, 'Western Europe'),
#  Text(0, 0, 'North America'),
#  Text(0, 0, 'Africa'),
#  Text(0, 0, 'South Asia'),
#  Text(0, 0, 'Northern Europe'),
#  Text(0, 0, 'East Asia'),
#  Text(0, 0, 'Middle East'),
#  Text(0, 0, 'Southeast Asia')]

# %%
sns.violinplot(x='Region',y='EduExpense2016',data=df5, hue='ThirdWorld')

# %%
chart = sns.boxplot(x='Region',y='EduExpense2016', data=df5, hue='ThirdWorld')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Eastern Europe'),
#  Text(0, 0, 'South America'),
#  Text(0, 0, 'Western Asia'),
#  Text(0, 0, 'Australia and Oceanea'),
#  Text(0, 0, 'Western Europe'),
#  Text(0, 0, 'North America'),
#  Text(0, 0, 'Africa'),
#  Text(0, 0, 'South Asia'),
#  Text(0, 0, 'Northern Europe'),
#  Text(0, 0, 'East Asia'),
#  Text(0, 0, 'Middle East'),
#  Text(0, 0, 'Southeast Asia')]

# %%
sns.heatmap(df5.corr(),
            square=True,
            linewidths=0.25,    
            linecolor=(0,0,0),
           cmap=sns.color_palette("coolwarm"),
           annot=True)

# %%
sns.pairplot(df5)

# %%
sns.pairplot(df5,hue='ThirdWorld', markers=["o", "D"])

# %%
sns.pairplot(df5, vars = ['Primary2015', 'EduExpense2015'], hue='ThirdWorld', markers=["o", "D"])

# %%
chart = sns.relplot(data=df5,
                    x="Primary2015", 
                    y="EduExpense2015", 
                    hue="ThirdWorld", 
                    size="EduExpense2016",
                    sizes=(40, 400), 
                    alpha=.5, 
                    palette=sns.color_palette("muted",len(df5['ThirdWorld'].unique())),
                    height=6)

# %%
sns.jointplot(data=df5,
               x="Primary2015", 
               y="EduExpense2015",
               color=(102/255,205/255,170/255))  # rgb
