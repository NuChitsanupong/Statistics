# %%
import os
os.chdir('????')
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-19e26919f103> in <module>
#       1 import os
# ----> 2 os.chdir('????')
#       3 os.getcwd()
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: '????'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
regions = pd.read_excel('regions.xlsx')
regions.head()
# Out:
#       CountryName                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %%
df = pd.read_excel('schoolEnroll_secondary_grossPercent.xlsx',sheet_name='Data')
df
# Out:
#                                           Series Name  Series Code  \
# 0              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 1              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 2              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 3              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 4              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 5              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 6              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 7              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 8              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 9              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 10             School enrollment, secondary (% gross)  SE.SEC.ENRR
# 11             School enrollment, secondary (% gross)  SE.SEC.ENRR
# 12             School enrollment, secondary (% gross)  SE.SEC.ENRR
# ...

# %%
df2 = df
df2.drop([217,218,219,220,221], inplace=True)

# %%
df2.replace({'..':np.nan}, inplace=True)
df2
# Out:
#                                 Series Name  Series Code  \
# 0    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 1    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 2    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 3    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 4    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 5    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 6    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 7    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 8    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 9    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 10   School enrollment, secondary (% gross)  SE.SEC.ENRR
# 11   School enrollment, secondary (% gross)  SE.SEC.ENRR
# 12   School enrollment, secondary (% gross)  SE.SEC.ENRR
# 13   School enrollment, secondary (% gross)  SE.SEC.ENRR
# 14   School enrollment, secondary (% gross)  SE.SEC.ENRR
# ...

# %%
sns.heatmap(df2.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df2.drop(['2018 [YR2018]','2019 [YR2019]'],axis=1, inplace=True)
df2.head()
# Out:
#                               Series Name  Series Code    Country Name  \
# 0  School enrollment, secondary (% gross)  SE.SEC.ENRR     Afghanistan
# 1  School enrollment, secondary (% gross)  SE.SEC.ENRR         Albania
# 2  School enrollment, secondary (% gross)  SE.SEC.ENRR         Algeria
# 3  School enrollment, secondary (% gross)  SE.SEC.ENRR  American Samoa
# 4  School enrollment, secondary (% gross)  SE.SEC.ENRR         Andorra
#
#   Country Code  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  \
# 0          AFG      10.849960            NaN       50.56725       51.75691
# 1          ALB      90.081741       71.07808       88.10389       89.79816
# 2          DZA      59.414188       65.11698       96.93728       99.61435
# 3          ASM            NaN            NaN            NaN            NaN
# 4          AND            NaN            NaN            NaN            NaN
#
#    2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# ...

# %%
sns.heatmap(df2.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df3 = pd.read_excel('gdp_per_capita.xlsx',sheet_name='Data')
df3.head()
# Out:
#                     Series Name     Series Code    Country Name Country Code  \
# 0  GDP per capita (current US$)  NY.GDP.PCAP.CD     Afghanistan          AFG
# 1  GDP per capita (current US$)  NY.GDP.PCAP.CD         Albania          ALB
# 2  GDP per capita (current US$)  NY.GDP.PCAP.CD         Algeria          DZA
# 3  GDP per capita (current US$)  NY.GDP.PCAP.CD  American Samoa          ASM
# 4  GDP per capita (current US$)  NY.GDP.PCAP.CD         Andorra          AND
#
#   1990 [YR1990] 2000 [YR2000] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 0            ..            ..       543.303       591.162       641.872
# 1        617.23       1126.68       4094.36       4437.18       4247.61
# 2       2408.69       1765.02       4480.79       5455.84       5592.22
# 3            ..            ..       10271.2       10294.3       11568.8
# 4       18878.5       21936.5       39736.4       41100.7       38392.9
#
# ...

# %%
df3
# Out:
#                                           Series Name     Series Code  \
# 0                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 5                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 6                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 7                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 8                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 9                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 10                       GDP per capita (current US$)  NY.GDP.PCAP.CD
# 11                       GDP per capita (current US$)  NY.GDP.PCAP.CD
# ...

# %%
df3.drop([217,218,219,220,221], inplace=True)

# %%
df3.replace({'..':np.nan}, inplace=True)
df3
# Out:
#                       Series Name     Series Code              Country Name  \
# 0    GDP per capita (current US$)  NY.GDP.PCAP.CD               Afghanistan
# 1    GDP per capita (current US$)  NY.GDP.PCAP.CD                   Albania
# 2    GDP per capita (current US$)  NY.GDP.PCAP.CD                   Algeria
# 3    GDP per capita (current US$)  NY.GDP.PCAP.CD            American Samoa
# 4    GDP per capita (current US$)  NY.GDP.PCAP.CD                   Andorra
# 5    GDP per capita (current US$)  NY.GDP.PCAP.CD                    Angola
# 6    GDP per capita (current US$)  NY.GDP.PCAP.CD       Antigua and Barbuda
# 7    GDP per capita (current US$)  NY.GDP.PCAP.CD                 Argentina
# 8    GDP per capita (current US$)  NY.GDP.PCAP.CD                   Armenia
# 9    GDP per capita (current US$)  NY.GDP.PCAP.CD                     Aruba
# 10   GDP per capita (current US$)  NY.GDP.PCAP.CD                 Australia
# ...

# %%
sns.heatmap(df3.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df3.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '1990 [YR1990]', '2000 [YR2000]', '2010 [YR2010]', '2011 [YR2011]',
#        '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]',
#        '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'],
#       dtype='object')

# %%
df3.drop(['2019 [YR2019]'],axis=1, inplace=True)
df3.head()
# Out:
#                     Series Name     Series Code    Country Name Country Code  \
# 0  GDP per capita (current US$)  NY.GDP.PCAP.CD     Afghanistan          AFG
# 1  GDP per capita (current US$)  NY.GDP.PCAP.CD         Albania          ALB
# 2  GDP per capita (current US$)  NY.GDP.PCAP.CD         Algeria          DZA
# 3  GDP per capita (current US$)  NY.GDP.PCAP.CD  American Samoa          ASM
# 4  GDP per capita (current US$)  NY.GDP.PCAP.CD         Andorra          AND
#
#    1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# 0            NaN            NaN     543.303042     591.162346     641.872034
# 1     617.230436    1126.683318    4094.358816    4437.177794    4247.614342
# 2    2408.688815    1765.022577    4480.785777    5455.842310    5592.221910
# 3            NaN            NaN   10271.224523   10294.302265   11568.793001
# 4   18878.505969   21936.530101   39736.354063   41100.729938   38392.943901
#
# ...

# %%
sns.heatmap(df3.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df4 = pd.read_excel('mobileSubscription_per100people.xlsx',sheet_name='Data')
df4.head()
# Out:
#                                       Series Name     Series Code  \
# 0  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 1  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 2  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 3  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 4  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
#
#      Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010]  \
# 0     Afghanistan          AFG             0             0       35.0031
# 1         Albania          ALB             0      0.952019       91.3281
# 2         Algeria          DZA    0.00182461      0.277042       91.1131
# 3  American Samoa          ASM             0       3.44512            ..
# 4         Andorra          AND             0        36.004       77.5557
#
#   2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# ...

# %%
df4
# Out:
#                                           Series Name     Series Code  \
# 0      Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 1      Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 2      Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 3      Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 4      Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 5      Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 6      Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 7      Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 8      Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 9      Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 10     Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 11     Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# ...

# %%
df4.drop([217,218,219,220,221], inplace=True)

# %%
df4.replace({'..':np.nan}, inplace=True)
df4
# Out:
#                                         Series Name     Series Code  \
# 0    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 1    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 2    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 3    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 4    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 5    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 6    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 7    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 8    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 9    Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 10   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 11   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 12   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# ...

# %%
sns.heatmap(df4.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df4.drop(['2019 [YR2019]'],axis=1, inplace=True)
df4.head()
# Out:
#                                       Series Name     Series Code  \
# 0  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 1  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 2  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 3  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 4  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
#
#      Country Name Country Code  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0     Afghanistan          AFG       0.000000       0.000000      35.003127
# 1         Albania          ALB       0.000000       0.952019      91.328053
# 2         Algeria          DZA       0.001825       0.277042      91.113073
# 3  American Samoa          ASM       0.000000       3.445115            NaN
# 4         Andorra          AND       0.000000      36.003976      77.555684
#
#    2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  \
# ...

# %%
sns.heatmap(df4.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df5 = regions.join(df2[['2000 [YR2000]','2015 [YR2015]']])
df5
# Out:
#                   CountryName                 Region  ThirdWorld  \
# 0                 Afghanistan             South Asia           1
# 1                     Albania         Eastern Europe           0
# 2                     Algeria                 Africa           0
# 3              American Samoa  Australia and Oceanea           0
# 4                     Andorra         Western Europe           0
# 5                      Angola                 Africa           1
# 6         Antigua and Barbuda          North America           0
# 7                   Argentina          South America           0
# 8                     Armenia           Western Asia           0
# 9                       Aruba          North America           0
# 10                  Australia  Australia and Oceanea           0
# 11                    Austria         Western Europe           0
# 12                 Azerbaijan           Western Asia           0
# ...

# %%
df5.rename(columns={'2000 [YR2000]':'Secondary2000','2015 [YR2015]':'Secondary2015'}, inplace=True)
df5.head()
# Out:
#       CountryName                 Region  ThirdWorld  Secondary2000  \
# 0     Afghanistan             South Asia           1            NaN
# 1         Albania         Eastern Europe           0       71.07808
# 2         Algeria                 Africa           0       65.11698
# 3  American Samoa  Australia and Oceanea           0            NaN
# 4         Andorra         Western Europe           0            NaN
#
#    Secondary2015
# 0       52.59281
# 1       97.38848
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df5 = df5.join(df3[['2000 [YR2000]','2015 [YR2015]']])
df5
# Out:
#                   CountryName                 Region  ThirdWorld  \
# 0                 Afghanistan             South Asia           1
# 1                     Albania         Eastern Europe           0
# 2                     Algeria                 Africa           0
# 3              American Samoa  Australia and Oceanea           0
# 4                     Andorra         Western Europe           0
# 5                      Angola                 Africa           1
# 6         Antigua and Barbuda          North America           0
# 7                   Argentina          South America           0
# 8                     Armenia           Western Asia           0
# 9                       Aruba          North America           0
# 10                  Australia  Australia and Oceanea           0
# 11                    Austria         Western Europe           0
# 12                 Azerbaijan           Western Asia           0
# ...

# %%
df5.rename(columns={'2000 [YR2000]':'GDP2000','2015 [YR2015]':'GDP2015'}, inplace=True)
df5.head()
# Out:
#       CountryName                 Region  ThirdWorld  Secondary2000  \
# 0     Afghanistan             South Asia           1            NaN
# 1         Albania         Eastern Europe           0       71.07808
# 2         Algeria                 Africa           0       65.11698
# 3  American Samoa  Australia and Oceanea           0            NaN
# 4         Andorra         Western Europe           0            NaN
#
#    Secondary2015       GDP2000       GDP2015
# 0       52.59281           NaN    578.466353
# 1       97.38848   1126.683318   3952.830781
# 2            NaN   1765.022577   4177.888966
# 3            NaN           NaN  11843.331183
# 4            NaN  21936.530101  36039.653496

# %%
df5 = df5.join(df4[['2000 [YR2000]','2015 [YR2015]']])
df5
# Out:
#                   CountryName                 Region  ThirdWorld  \
# 0                 Afghanistan             South Asia           1
# 1                     Albania         Eastern Europe           0
# 2                     Algeria                 Africa           0
# 3              American Samoa  Australia and Oceanea           0
# 4                     Andorra         Western Europe           0
# 5                      Angola                 Africa           1
# 6         Antigua and Barbuda          North America           0
# 7                   Argentina          South America           0
# 8                     Armenia           Western Asia           0
# 9                       Aruba          North America           0
# 10                  Australia  Australia and Oceanea           0
# 11                    Austria         Western Europe           0
# 12                 Azerbaijan           Western Asia           0
# ...

# %%
df5.rename(columns={'2000 [YR2000]':'MobileSubscription2000','2015 [YR2015]':'MobileSubscription2015'}, inplace=True)
df5.head()
# Out:
#       CountryName                 Region  ThirdWorld  Secondary2000  \
# 0     Afghanistan             South Asia           1            NaN
# 1         Albania         Eastern Europe           0       71.07808
# 2         Algeria                 Africa           0       65.11698
# 3  American Samoa  Australia and Oceanea           0            NaN
# 4         Andorra         Western Europe           0            NaN
#
#    Secondary2015       GDP2000       GDP2015  MobileSubscription2000  \
# 0       52.59281           NaN    578.466353                0.000000
# 1       97.38848   1126.683318   3952.830781                0.952019
# 2            NaN   1765.022577   4177.888966                0.277042
# 3            NaN           NaN  11843.331183                3.445115
# 4            NaN  21936.530101  36039.653496               36.003976
#
#    MobileSubscription2015
# 0               57.271068
# 1              117.659218
# 2              108.808940
# 3                     NaN
# ...

# %%
df5 = df5.dropna()
df5.head()
# Out:
#             CountryName          Region  ThirdWorld  Secondary2000  \
# 1               Albania  Eastern Europe           0       71.07808
# 6   Antigua and Barbuda   North America           0       79.66178
# 7             Argentina   South America           0       95.93661
# 8               Armenia    Western Asia           0       92.15199
# 11              Austria  Western Europe           0       98.69606
#
#     Secondary2015       GDP2000       GDP2015  MobileSubscription2000  \
# 1        97.38848   1126.683318   3952.830781                0.952019
# 6       108.23020  10920.842688  14526.588085               28.941276
# 7       106.94650   7708.100996  13789.060425               17.596451
# 8        86.00589    622.742139   3607.296697                0.569652
# 11      100.32100  24564.458295  44176.671743               75.806057
#
#     MobileSubscription2015
# 1               117.659218
# 6               188.102516
# 7               143.566834
# ...

# %%
sns.heatmap(df5.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df5.shape
# Out:
# (107, 9)

# %%
df5.to_csv('Secondary_GDP_MobileSubscription_2000_2015.csv',index=False)
