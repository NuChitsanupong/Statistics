# %%
import os
os.chdir('???')
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-94d77baee8d6> in <module>
#       1 import os
# ----> 2 os.chdir('???')
#       3 os.getcwd()
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: '???'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Secondary_GDP_MobileSubscription_2000_2015.csv',sep=',',header='infer')
df.head()
# Out:
#            CountryName          Region  ThirdWorld  Secondary2000  \
# 0              Albania  Eastern Europe           0       71.07808
# 1  Antigua and Barbuda   North America           0       79.66178
# 2            Argentina   South America           0       95.93661
# 3              Armenia    Western Asia           0       92.15199
# 4              Austria  Western Europe           0       98.69606
#
#    Secondary2015       GDP2000       GDP2015  MobileSubscription2000  \
# 0       97.38848   1126.683318   3952.830781                0.952019
# 1      108.23020  10920.842688  14526.588085               28.941276
# 2      106.94650   7708.100996  13789.060425               17.596451
# 3       86.00589    622.742139   3607.296697                0.569652
# 4      100.32100  24564.458295  44176.671743               75.806057
#
#    MobileSubscription2015
# 0              117.659218
# 1              188.102516
# 2              143.566834
# 3              118.421714
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.describe()
# Out:
#        ThirdWorld  Secondary2000  Secondary2015       GDP2000        GDP2015  \
# count  107.000000     107.000000     107.000000    107.000000     107.000000
# mean     0.177570      75.145444      90.245600   8279.796390   16696.558103
# std      0.383949      32.370309      27.107262  10594.074034   20112.551172
# min      0.000000       6.197350      20.093220    124.460800     360.853384
# 25%      0.000000      58.018090      80.318485    774.183139    3001.911981
# 50%      0.000000      82.507890      97.388480   3384.694861    9160.734157
# 75%      0.000000      96.523475     106.017900  11724.987970   21788.232020
# max      1.000000     151.851160     163.934700  48735.995492  100428.367963
#
#        MobileSubscription2000  MobileSubscription2015
# count              107.000000              107.000000
# mean                21.067550              112.733888
# std                 24.900640               38.141996
# min                  0.000000               29.451748
# ...

# %%
df.hist(figsize=(16,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A24E122B38>,
# ...
#       dtype=object)

# %%
df.hist(column='MobileSubscription2015', bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A24E346198>]],
#       dtype=object)

# %%
sns.distplot(df['MobileSubscription2015'], bins=10, hist=True, kde=False, rug=False)

# %%
sns.distplot(df['MobileSubscription2015'], bins=10, hist=True, kde=True, rug=False)

# %%
sns.distplot(df['MobileSubscription2015'], hist=False, kde=True, rug=True)

# %%
df.Region.unique()
# Out:
# array(['Eastern Europe', 'North America', 'South America', 'Western Asia',
#        'Western Europe', 'Middle East', 'South Asia', 'Africa',
#        'Southeast Asia', 'Northern Europe', 'East Asia',
#        'Australia and Oceanea'], dtype=object)

# %%
df[df.Region=='Africa']
# Out:
#      CountryName  Region  ThirdWorld  Secondary2000  Secondary2015  \
# 10         Benin  Africa           1       21.83777       58.84676
# 15  Burkina Faso  Africa           1       10.42248       33.71873
# 16    Cabo Verde  Africa           0       68.67609       94.72112
# 17      Cameroon  Africa           0       27.57544       59.03209
# 19          Chad  Africa           1       10.76674       22.41506
# 28      Djibouti  Africa           1       14.04512       46.76042
# 34      Eswatini  Africa           0       43.83822       76.03505
# 35      Ethiopia  Africa           1       13.53887       34.93947
# 40         Ghana  Africa           0       35.12860       67.90667
# 58       Lesotho  Africa           1       28.28289       60.67609
# 59       Liberia  Africa           1       35.93726       37.90350
# 63        Malawi  Africa           1       31.28883       40.77254
# 65          Mali  Africa           1       17.45372       41.72014
# ...

# %%
df[df.Region=='Africa'].hist(figsize=(16,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A24E5CC710>,
# ...
#       dtype=object)

# %%
df[df.Region=='North America'].hist(figsize=(16,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A24EF27DA0>,
# ...
#       dtype=object)

# %%
df[df.Region=='Southeast Asia'].hist(figsize=(16,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A24F596B38>,
# ...
#       dtype=object)

# %%
sns.distplot(df[df.Region=='Africa']["Secondary2000"], bins=10, hist=True, kde=False, rug=False, label='Africa')
sns.distplot(df[df.Region=='North America']["Secondary2000"], bins=10, hist=True, kde=False, rug=False, label='North America')
sns.distplot(df[df.Region=='Southeast Asia']["Secondary2000"], bins=10, hist=True, kde=False, rug=False, label='Southeast Asia')
plt.legend()

# %%
sns.distplot(df[df.Region=='Africa']["Secondary2015"], bins=10, hist=True, kde=False, rug=False, label='Africa')
sns.distplot(df[df.Region=='North America']["Secondary2015"], bins=10, hist=True, kde=False, rug=False, label='North America')
sns.distplot(df[df.Region=='Southeast Asia']["Secondary2015"], bins=10, hist=True, kde=False, rug=False, label='Southeast Asia')
plt.legend()

# %%
sns.distplot(df[df.Region=='Africa']["MobileSubscription2000"], bins=10, hist=True, kde=False, rug=False, label='Africa')
sns.distplot(df[df.Region=='North America']["MobileSubscription2000"], bins=10, hist=True, kde=False, rug=False, label='North America')
sns.distplot(df[df.Region=='Southeast Asia']["MobileSubscription2000"], bins=10, hist=True, kde=False, rug=False, label='Southeast Asia')
plt.legend()

# %%
sns.distplot(df[df.Region=='Africa']["MobileSubscription2015"], bins=10, hist=True, kde=False, rug=False, label='Africa')
sns.distplot(df[df.Region=='North America']["MobileSubscription2015"], bins=10, hist=True, kde=False, rug=False, label='North America')
sns.distplot(df[df.Region=='Southeast Asia']["MobileSubscription2015"], bins=10, hist=True, kde=False, rug=False, label='Southeast Asia')
plt.legend()

# %%
sns.distplot(df[df.Region=='Africa']["GDP2000"], bins=10, hist=True, kde=False, rug=False, label='Africa')
sns.distplot(df[df.Region=='North America']["GDP2000"], bins=10, hist=True, kde=False, rug=False, label='North America')
sns.distplot(df[df.Region=='Southeast Asia']["GDP2000"], bins=10, hist=True, kde=False, rug=False, label='Southeast Asia')
plt.legend()

# %%
sns.distplot(df[df.Region=='Africa']["GDP2015"], bins=10, hist=True, kde=False, rug=False, label='Africa')
sns.distplot(df[df.Region=='North America']["GDP2015"], bins=10, hist=True, kde=False, rug=False, label='North America')
sns.distplot(df[df.Region=='Southeast Asia']["GDP2015"], bins=10, hist=True, kde=False, rug=False, label='Southeast Asia')
plt.legend()

# %%
sns.boxplot(x='MobileSubscription2015', data=df)

# %%
sns.boxplot(x='Region',y='MobileSubscription2015', data=df)

# %%
chart = sns.boxplot(x='Region',y='MobileSubscription2015', data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Eastern Europe'),
#  Text(0, 0, 'North America'),
#  Text(0, 0, 'South America'),
#  Text(0, 0, 'Western Asia'),
#  Text(0, 0, 'Western Europe'),
#  Text(0, 0, 'Middle East'),
#  Text(0, 0, 'South Asia'),
#  Text(0, 0, 'Africa'),
#  Text(0, 0, 'Southeast Asia'),
#  Text(0, 0, 'Northern Europe'),
#  Text(0, 0, 'East Asia'),
#  Text(0, 0, 'Australia and Oceanea')]

# %%
sns.violinplot(x='Region',y='MobileSubscription2015',data=df, hue='ThirdWorld')

# %%
chart = sns.boxplot(x='Region',y='MobileSubscription2015', data=df, hue='ThirdWorld')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Eastern Europe'),
#  Text(0, 0, 'North America'),
#  Text(0, 0, 'South America'),
#  Text(0, 0, 'Western Asia'),
#  Text(0, 0, 'Western Europe'),
#  Text(0, 0, 'Middle East'),
#  Text(0, 0, 'South Asia'),
#  Text(0, 0, 'Africa'),
#  Text(0, 0, 'Southeast Asia'),
#  Text(0, 0, 'Northern Europe'),
#  Text(0, 0, 'East Asia'),
#  Text(0, 0, 'Australia and Oceanea')]

# %%
sns.heatmap(df.corr(),
            square=True,
            linewidths=0.25,    
            linecolor=(0,0,0),
           cmap=sns.color_palette("coolwarm"),
           annot=True)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='ThirdWorld', markers=["o", "D"])
# Out:
# C:\Users\Nu\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Nu\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.pairplot(df, vars = ['Secondary2000', 'MobileSubscription2000'], hue='ThirdWorld', markers=["o", "D"])

# %%
sns.pairplot(df, vars = ['Secondary2015', 'GDP2015'], hue='ThirdWorld', markers=["o", "D"])

# %%
sns.pairplot(df, vars = ['MobileSubscription2000', 'GDP2000'], hue='ThirdWorld', markers=["o", "D"])

# %%
sns.pairplot(df, vars = ['MobileSubscription2015', 'GDP2015'], hue='ThirdWorld', markers=["o", "D"])

# %%
sns.pairplot(df, vars = ['GDP2000', 'GDP2015'], hue='ThirdWorld', markers=["o", "D"])

# %%
chart = sns.relplot(data=df,
                    x="Secondary2000", 
                    y="MobileSubscription2000", 
                    hue="ThirdWorld", 
                    size="MobileSubscription2015",
                    sizes=(40, 400), 
                    alpha=.5, 
                    palette=sns.color_palette("muted",len(df['ThirdWorld'].unique())),
                    height=6)

# %%
sns.jointplot(data=df,
               x="Secondary2000", 
               y="MobileSubscription2000",
               color=(102/255,205/255,170/255))  # rgb
