# %%
import os
os.chdir('????')
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-350-19e26919f103> in <module>
#       1 import os
# ----> 2 os.chdir('????')
#       3 os.getcwd()
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: '????'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
regions = pd.read_excel('regions.xlsx')
regions.head()
# Out:
#       CountryName                 Region  ThirdWorld
# 0     Afghanistan             South Asia           1
# 1         Albania         Eastern Europe           0
# 2         Algeria                 Africa           0
# 3  American Samoa  Australia and Oceanea           0
# 4         Andorra         Western Europe           0

# %%
df = pd.read_excel('schoolEnroll_secondary_grossPercent.xlsx',sheet_name='Data')
df
# Out:
#                                           Series Name  Series Code  \
# 0              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 1              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 2              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 3              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 4              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 5              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 6              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 7              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 8              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 9              School enrollment, secondary (% gross)  SE.SEC.ENRR
# 10             School enrollment, secondary (% gross)  SE.SEC.ENRR
# 11             School enrollment, secondary (% gross)  SE.SEC.ENRR
# 12             School enrollment, secondary (% gross)  SE.SEC.ENRR
# ...

# %%
df.drop([217,218,219,220,221], inplace=True)

# %%
df.replace({'..':np.nan}, inplace=True)
df
# Out:
#                                 Series Name  Series Code  \
# 0    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 1    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 2    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 3    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 4    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 5    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 6    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 7    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 8    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 9    School enrollment, secondary (% gross)  SE.SEC.ENRR
# 10   School enrollment, secondary (% gross)  SE.SEC.ENRR
# 11   School enrollment, secondary (% gross)  SE.SEC.ENRR
# 12   School enrollment, secondary (% gross)  SE.SEC.ENRR
# 13   School enrollment, secondary (% gross)  SE.SEC.ENRR
# 14   School enrollment, secondary (% gross)  SE.SEC.ENRR
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.drop(['2018 [YR2018]','2019 [YR2019]'],axis=1, inplace=True)
df.head()
# Out:
#                               Series Name  Series Code    Country Name  \
# 0  School enrollment, secondary (% gross)  SE.SEC.ENRR     Afghanistan
# 1  School enrollment, secondary (% gross)  SE.SEC.ENRR         Albania
# 2  School enrollment, secondary (% gross)  SE.SEC.ENRR         Algeria
# 3  School enrollment, secondary (% gross)  SE.SEC.ENRR  American Samoa
# 4  School enrollment, secondary (% gross)  SE.SEC.ENRR         Andorra
#
#   Country Code  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  \
# 0          AFG      10.849960            NaN       50.56725       51.75691
# 1          ALB      90.081741       71.07808       88.10389       89.79816
# 2          DZA      59.414188       65.11698       96.93728       99.61435
# 3          ASM            NaN            NaN            NaN            NaN
# 4          AND            NaN            NaN            NaN            NaN
#
#    2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df2 = regions.join(df)
df2
# Out:
#                   CountryName                 Region  ThirdWorld  \
# 0                 Afghanistan             South Asia           1
# 1                     Albania         Eastern Europe           0
# 2                     Algeria                 Africa           0
# 3              American Samoa  Australia and Oceanea           0
# 4                     Andorra         Western Europe           0
# 5                      Angola                 Africa           1
# 6         Antigua and Barbuda          North America           0
# 7                   Argentina          South America           0
# 8                     Armenia           Western Asia           0
# 9                       Aruba          North America           0
# 10                  Australia  Australia and Oceanea           0
# 11                    Austria         Western Europe           0
# 12                 Azerbaijan           Western Asia           0
# ...

# %%
df2.drop(['CountryName','ThirdWorld','Series Name','Series Code','Country Name','Country Code'],axis=1, inplace=True)
df2.head()
# Out:
#                   Region  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0             South Asia      10.849960            NaN       50.56725
# 1         Eastern Europe      90.081741       71.07808       88.10389
# 2                 Africa      59.414188       65.11698       96.93728
# 3  Australia and Oceanea            NaN            NaN            NaN
# 4         Western Europe            NaN            NaN            NaN
#
#    2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  \
# 0       51.75691       53.61805       53.57513       52.58290       52.59281
# 1       89.79816       92.28983       96.25608       97.68487       97.38848
# 2       99.61435            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    2016 [YR2016]  2017 [YR2017]
# 0        50.6454       53.79764
# ...

# %%
df2
# Out:
#                     Region  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0               South Asia      10.849960            NaN       50.56725
# 1           Eastern Europe      90.081741       71.07808       88.10389
# 2                   Africa      59.414188       65.11698       96.93728
# 3    Australia and Oceanea            NaN            NaN            NaN
# 4           Western Europe            NaN            NaN            NaN
# 5                   Africa       8.403450       12.26628       26.25922
# 6            North America            NaN       79.66178      112.79580
# 7            South America      71.489578       95.93661       99.50126
# 8             Western Asia            NaN       92.15199      104.71330
# 9            North America            NaN       96.51617       95.82354
# 10   Australia and Oceanea            NaN            NaN            NaN
# 11          Western Europe     101.170898       98.69606       98.80721
# ...

# %%
df4 = df2.groupby(["Region"]).sum().reset_index()
df4
# Out:
#                    Region  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0                  Africa     842.998200     1216.98003     1428.17049
# 1   Australia and Oceanea     332.881341      633.38457      418.45087
# 2               East Asia     279.473339      304.42595      451.88042
# 3          Eastern Europe     936.726524     1055.01463     1333.25752
# 4             Middle East     736.440994      949.10060      937.81418
# 5           North America    1033.765118     1590.66904     2239.91476
# 6         Northern Europe     989.316765     1113.76630     1079.30551
# 7            Sint Maarten       0.000000        0.00000        0.00000
# 8           South America     494.865376      686.12488      967.48014
# 9              South Asia     169.671192      211.71584      416.56008
# 10         Southeast Asia     257.779371      305.44327      410.35436
# 11               Thailand      28.517540        0.00000       82.42885
# ...

# %%
df4.drop([7,11], inplace=True)

# %%
df4
# Out:
#                    Region  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 0                  Africa     842.998200     1216.98003     1428.17049
# 1   Australia and Oceanea     332.881341      633.38457      418.45087
# 2               East Asia     279.473339      304.42595      451.88042
# 3          Eastern Europe     936.726524     1055.01463     1333.25752
# 4             Middle East     736.440994      949.10060      937.81418
# 5           North America    1033.765118     1590.66904     2239.91476
# 6         Northern Europe     989.316765     1113.76630     1079.30551
# 8           South America     494.865376      686.12488      967.48014
# 9              South Asia     169.671192      211.71584      416.56008
# 10         Southeast Asia     257.779371      305.44327      410.35436
# 12           Western Asia     399.555046      518.81428      465.37659
# 13         Western Europe    1064.969799     1488.91962     1613.51882
#
# ...

# %%
df4.rename(columns={'1990 [YR1990]':'1990','2000 [YR2000]':'2000','2010 [YR2010]':'2010','2011 [YR2011]':'2011','2012 [YR2012]':'2012','2013 [YR2013]':'2013','2014 [YR2014]':'2014','2015 [YR2015]':'2015','2016 [YR2016]':'2016','2017 [YR2017]':'2017'}, inplace=True)
df4.head()
# Out:
#                   Region        1990        2000        2010        2011  \
# 0                 Africa  842.998200  1216.98003  1428.17049  1833.98041
# 1  Australia and Oceanea  332.881341   633.38457   418.45087   451.21987
# 2              East Asia  279.473339   304.42595   451.88042   274.81840
# 3         Eastern Europe  936.726524  1055.01463  1333.25752  1336.93932
# 4            Middle East  736.440994   949.10060   937.81418   941.48566
#
#          2012        2013        2014        2015        2016        2017
# 2  GDP per capita (current US$)  NY.GDP.PCAP.CD         Algeria          DZA
# 3  GDP per capita (current US$)  NY.GDP.PCAP.CD  American Samoa          ASM
# 4  GDP per capita (current US$)  NY.GDP.PCAP.CD         Andorra          AND
#
#   1990 [YR1990] 2000 [YR2000] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 0            ..            ..       543.303       591.162       641.872
# 1        617.23       1126.68       4094.36       4437.18       4247.61
# 2       2408.69       1765.02       4480.79       5455.84       5592.22
# 3            ..            ..       10271.2       10294.3       11568.8
# 4       18878.5       21936.5       39736.4       41100.7       38392.9
#
# ...

# %%
df3.drop([217,218,219,220,221], inplace=True)

# %%
df3.replace({'..':np.nan}, inplace=True)
df3
# Out:
#                       Series Name     Series Code              Country Name  \
# 0    GDP per capita (current US$)  NY.GDP.PCAP.CD               Afghanistan
# 1    GDP per capita (current US$)  NY.GDP.PCAP.CD                   Albania
# 2    GDP per capita (current US$)  NY.GDP.PCAP.CD                   Algeria
# 3    GDP per capita (current US$)  NY.GDP.PCAP.CD            American Samoa
# 4    GDP per capita (current US$)  NY.GDP.PCAP.CD                   Andorra
# 5    GDP per capita (current US$)  NY.GDP.PCAP.CD                    Angola
# 6    GDP per capita (current US$)  NY.GDP.PCAP.CD       Antigua and Barbuda
# 7    GDP per capita (current US$)  NY.GDP.PCAP.CD                 Argentina
# 8    GDP per capita (current US$)  NY.GDP.PCAP.CD                   Armenia
# 9    GDP per capita (current US$)  NY.GDP.PCAP.CD                     Aruba
# 10   GDP per capita (current US$)  NY.GDP.PCAP.CD                 Australia
# ...

# %%
sns.heatmap(df3.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df3.drop(['2018 [YR2018]','2019 [YR2019]'],axis=1, inplace=True)
df3.head()
# Out:
#                     Series Name     Series Code    Country Name Country Code  \
# 0  GDP per capita (current US$)  NY.GDP.PCAP.CD     Afghanistan          AFG
# 1  GDP per capita (current US$)  NY.GDP.PCAP.CD         Albania          ALB
# 2  GDP per capita (current US$)  NY.GDP.PCAP.CD         Algeria          DZA
# 3  GDP per capita (current US$)  NY.GDP.PCAP.CD  American Samoa          ASM
# 4  GDP per capita (current US$)  NY.GDP.PCAP.CD         Andorra          AND
#
#    1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# 0            NaN            NaN     543.303042     591.162346     641.872034
# 1     617.230436    1126.683318    4094.358816    4437.177794    4247.614342
# 2    2408.688815    1765.022577    4480.785777    5455.842310    5592.221910
# 3            NaN            NaN   10271.224523   10294.302265   11568.793001
# 4   18878.505969   21936.530101   39736.354063   41100.729938   38392.943901
#
# ...

# %%
sns.heatmap(df3.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df3 = regions.join(df3)
df3
# Out:
#                   CountryName                 Region  ThirdWorld  \
# 0                 Afghanistan             South Asia           1
# 1                     Albania         Eastern Europe           0
# 2                     Algeria                 Africa           0
# 3              American Samoa  Australia and Oceanea           0
# 4                     Andorra         Western Europe           0
# 5                      Angola                 Africa           1
# 6         Antigua and Barbuda          North America           0
# 7                   Argentina          South America           0
# 8                     Armenia           Western Asia           0
# 9                       Aruba          North America           0
# 10                  Australia  Australia and Oceanea           0
# 11                    Austria         Western Europe           0
# 12                 Azerbaijan           Western Asia           0
# ...

# %%
df3.drop(['CountryName','ThirdWorld','Series Name','Series Code','Country Name','Country Code'],axis=1, inplace=True)
df3.head()
# Out:
#                   Region  1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# 
isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.heatmap(df5.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df4.shape
# Out:
# (10, 13)

# %%
df5.shape
# Out:
# (10, 13)

# %%
df4.to_csv('Secondary.csv',index=False)

# %%
df5.to_csv('GDP.csv',index=False)

# %%
test = df2.groupby(['Region'])
df2_count = test.count()
df2_count
# Out:
#                        1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# Region
# Africa                            34             34             29
# Australia and Oceanea              6              9              5
# East Asia                          4              4              5
# Eastern Europe                    10             12             14
# Middle East                       11             12             11
# North America                     14             20             25
# Northern Europe                   10             10             10
# Sint Maarten                       0              0              0
# South America                      8              9             11
# South Asia                         5              5              7
# Southeast Asia                     6              6              6
# Thailand                           1              0              1
# Western Asia                       4              6              5
# ...

# %%
df2_count.drop(['Sint Maarten','Thailand'], inplace=True)
df2_count
# Out:
#                        1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# Region
# Africa                            34             34             29
# Australia and Oceanea              6              9              5
# East Asia                          4              4              5
# Eastern Europe                    10             12             14
# Middle East                       11             12             11
# North America                     14             20             25
# Northern Europe                   10             10             10
# South America                      8              9             11
# South Asia                         5              5              7
# Southeast Asia                     6              6              6
# Western Asia                       4              6              5
# Western Europe                    12             15             15
#
#                        2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# Region
# ...

# %%
df2_count.rename(columns={'1990 [YR1990]':'1990','2000 [YR2000]':'2000','2010 [YR2010]':'2010','2011 [YR2011]':'2011','2012 [YR2012]':'2012','2013 [YR2013]':'2013','2014 [YR2014]':'2014','2015 [YR2015]':'2015','2016 [YR2016]':'2016','2017 [YR2017]':'2017'}, inplace=True)
df2_count = df2_count.T
df2_count
# Out:
# Region  Africa  Australia and Oceanea  East Asia  Eastern Europe  Middle East  \
# 1990        34                      6          4              10           11
# 2000        34                      9          4              12           12
# 2010        29                      5          5              14           11
# 2011        38                      5          3              14           11
# 2012        32                      7          3              15           11
# 2013        29                      3          3              14           12
# 2014        33                      6          3              14            9
# 2015        33                      7          4              14            8
# 2016        30                      7          3              13            8
# 2017        28                      2          3              10            8
#
# Region  North America  Northern Europe  South America  South Asia  \
# ...

# %%
df2_count = df2_count.reset_index()

# %%
df2_count
# Out:
# Region index  Africa  Australia and Oceanea  East Asia  Eastern Europe  \
# 0       1990      34                      6          4              10
# 1       2000      34                      9          4              12
# 2       2010      29                      5          5              14
# 3       2011      38                      5          3              14
# 4       2012      32                      7          3              15
# 5       2013      29                      3          3              14
# 6       2014      33                      6          3              14
# 7       2015      33                      7          4              14
# 8       2016      30                      7          3              13
# 9       2017      28                      2          3              10
#
# Region  Middle East  North America  Northern Europe  South America  \
# 0                11             14               10              8
# ...

# %%
df2_count.rename(columns={'index':'Year'}, inplace=True)
df2_count
# Out:
# Region  Year  Africa  Australia and Oceanea  East Asia  Eastern Europe  \
# 0       1990      34                      6          4              10
# 1       2000      34                      9          4              12
# 2       2010      29                      5          5              14
# 3       2011      38                      5          3              14
# 4       2012      32                      7          3              15
# 5       2013      29                      3          3              14
# 6       2014      33                      6          3              14
# 7       2015      33                      7          4              14
# 8       2016      30                      7          3              13
# 9       2017      28                      2          3              10
#
# Region  Middle East  North America  Northern Europe  South America  \
# 0                11             14               10              8
# ...

# %%
df2_count.to_csv('Secondary_count.csv',index=False)

# %%
test = df3.groupby(['Region'])
df3_count = test.count()
df3_count
# Out:
#                        1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# Region
# Africa                            50             51             53
# Australia and Oceanea             14             15             17
# East Asia                          6              6              6
# Eastern Europe                    10             17             17
# Middle East                       15             15             15
# North America                     26             27             28
# Northern Europe                    8             13             13
# Sint Maarten                       0              0              0
# South America                     12             12             12
# South Asia                         7              7              8
# Southeast Asia                     7             10             10
# Thailand                           1              1              1
# Western Asia                       8              8              8
# ...

# %%
df3_count.drop(['Sint Maarten','Thailand'], inplace=True)
df3_count
# Out:
#                        1990 [YR1990]  2000 [YR2000]  2010 [YR2010]  \
# Region
# Africa                            50             51             53
# Australia and Oceanea             14             15             17
# East Asia                          6              6              6
# Eastern Europe                    10             17             17
# Middle East                       15             15             15
# North America                     26             27             28
# Northern Europe                    8             13             13
# South America                     12             12             12
# South Asia                         7              7              8
# Southeast Asia                     7             10             10
# Western Asia                       8              8              8
# Western Europe                    16             17             17
#
#                        2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# Region
# ...

# %%
df3_count.rename(columns={'1990 [YR1990]':'1990','2000 [YR2000]':'2000','2010 [YR2010]':'2010','2011 [YR2011]':'2011','2012 [YR2012]':'2012','2013 [YR2013]':'2013','2014 [YR2014]':'2014','2015 [YR2015]':'2015','2016 [YR2016]':'2016','2017 [YR2017]':'2017'}, inplace=True)
df3_count = df3_count.T
df3_count
# Out:
# Region  Africa  Australia and Oceanea  East Asia  Eastern Europe  Middle East  \
# 1990        50                     14          6              10           15
# 2000        51                     15          6              17           15
# 2010        53                     17          6              17           15
# 2011        53                     17          6              17           15
# 2012        52                     17          6              17           15
# 2013        53                     17          6              17           15
# 2014        53                     17          6              17           15
# 2015        53                     17          6              17           15
# 2016        53                     17          6              17           15
# 2017        52                     17          6              17           15
#
# Region  North America  Northern Europe  South America  South Asia  \
# ...

# %%
df3_count = df3_count.reset_index()

# %%
df3_count
# Out:
# Region index  Africa  Australia and Oceanea  East Asia  Eastern Europe  \
# 0       1990      50                     14          6              10
# 1       2000      51                     15          6              17
# 2       2010      53                     17          6              17
# 3       2011      53                     17          6              17
# 4       2012      52                     17          6              17
# 5       2013      53                     17          6              17
# 6       2014      53                     17          6              17
# 7       2015      53                     17          6              17
# 8       2016      53                     17          6              17
# 9       2017      52                     17          6              17
#
# Region  Middle East  North America  Northern Europe  South America  \
# 0                15             26                8             12
# ...

# %%
df3_count.rename(columns={'index':'Year'}, inplace=True)
df3_count
# Out:
# Region  Year  Africa  Australia and Oceanea  East Asia  Eastern Europe  \
# 0       1990      50                     14          6              10
# 1       2000      51                     15          6              17
# 2       2010      53                     17          6              17
# 3       2011      53                     17          6              17
# 4       2012      52                     17          6              17
# 5       2013      53                     17          6              17
# 6       2014      53                     17          6              17
# 7       2015      53                     17          6              17
# 8       2016      53                     17          6              17
# 9       2017      52                     17          6              17
#
# Region  Middle East  North America  Northern Europe  South America  \
# 0                15             26                8             12
# ...

# %%
df3_count.to_csv('GDP_count.csv',index=False)
