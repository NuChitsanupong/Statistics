# %%
import os
os.chdir('???')
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-94d77baee8d6> in <module>
#       1 import os
# ----> 2 os.chdir('???')
#       3 os.getcwd()
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: '???'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as pyo
import plotly.graph_objs as go
# %matplotlib inline

# %%
df = pd.read_csv('Secondary.csv')
df
# Out:
#    Year    Africa  Australia and Oceanea  East Asia  Eastern Europe  \
# 0  1990   842.998                332.881    279.473         936.727
# 1  2000  1216.980                633.385    304.426        1055.015
# 2  2010  1428.170                418.451    451.880        1333.258
# 3  2011  1833.980                451.220    274.818        1336.939
# 4  2012  1590.086                553.576    296.997        1432.003
# 5  2013  1549.988                326.836    293.156        1365.681
# 6  2014  1775.198                585.520    294.472        1361.586
# 7  2015  1701.209                670.226    389.567        1360.212
# 8  2016  1652.110                626.334    302.601        1270.513
# 9  2017  1538.244                264.902    305.680         983.402
#
#    Middle East  North America  Northern Europe  South America  South Asia  \
# 0      736.441       1033.765          989.317        494.865     169.671
# ...

# %%
df = pd.read_csv('Secondary_count.csv')
df
# Out:
#    Year  Africa  Australia and Oceanea  East Asia  Eastern Europe  \
# 0  1990      34                      6          4              10
# 1  2000      34                      9          4              12
# 2  2010      29                      5          5              14
# 3  2011      38                      5          3              14
# 4  2012      32                      7          3              15
# 5  2013      29                      3          3              14
# 6  2014      33                      6          3              14
# 7  2015      33                      7          4              14
# 8  2016      30                      7          3              13
# 9  2017      28                      2          3              10
#
#    Middle East  North America  Northern Europe  South America  South Asia  \
# 0           11             14               10              8           5
# 1           12             20               10              9           5
# ...

# %%
df = pd.read_csv('Secondary_divByCountry.csv')
df
# Out:
#    Year  Africa  Australia and Oceanea  East Asia  Eastern Europe  \
# 0  1990  24.794                 55.480     69.868          93.673
# 1  2000  35.794                 70.376     76.107          87.918
# 2  2010  49.247                 83.690     90.376          95.233
# 3  2011  48.263                 90.244     91.606          95.496
# 4  2012  49.690                 79.082     98.999          95.467
# 5  2013  53.448                108.945     97.719          97.549
# 6  2014  53.794                 97.587     98.157          97.256
# 7  2015  51.552                 95.747     97.392          97.158
# 8  2016  55.070                 89.476    100.867          97.732
# 9  2017  54.937                132.451    101.893          98.340
#
#    Middle East  North America  Northern Europe  South America  South Asia  \
# 0       66.949         73.840           98.932         61.858      33.934
# 1       79.092         79.533          111.377         76.236      42.343
# ...

# %%
df2 = pd.read_csv('GDP.csv')
df2
# Out:
#    Year     Africa  Australia and Oceanea  East Asia  Eastern Europe  \
# 0  1990   53747.63               73866.77   56219.89        27925.38
# 1  2000   57297.96               85229.20   93379.96        46785.96
# 2  2010  136022.70              183813.30  158591.50       148954.10
# 3  2011  147760.00              205024.10  183410.40       162872.70
# 4  2012  154210.40              221089.90  196653.80       153319.60
# 5  2013  155113.30              225808.40  205452.40       161641.70
# 6  2014  151706.00              225450.80  211823.10       162045.70
# 7  2015  127973.00              215672.70  191354.40       135938.60
# 8  2016  123141.50              216720.50  195830.70       138293.80
# 9  2017  131507.80              230658.40  207935.20       152246.30
#
#    Middle East  North America  Northern Europe  South America  South Asia  \
# 0     115473.9       160635.7         190604.4       23102.85    3229.623
# ...

# %%
df2 = pd.read_csv('GDP_count.csv')
df2
# Out:
#    Year  Africa  Australia and Oceanea  East Asia  Eastern Europe  \
# 0  1990      50                     14          6              10
# 1  2000      51                     15          6              17
# 2  2010      53                     17          6              17
# 3  2011      53                     17          6              17
# 4  2012      52                     17          6              17
# 5  2013      53                     17          6              17
# 6  2014      53                     17          6              17
# 7  2015      53                     17          6              17
# 8  2016      53                     17          6              17
# 9  2017      52                     17          6              17
#
#    Middle East  North America  Northern Europe  South America  South Asia  \
# 0           15             26                8             12           7
# 1           15             27               13             12           7
# ...

# %%
df2 = pd.read_csv('GDP_divByCountry.csv')
df2
# Out:
#    Year    Africa  Australia and Oceanea  East Asia  Eastern Europe  \
# 0  1990  1074.953               5276.198   9369.982        2792.538
# 1  2000  1123.489               5681.947  15563.327        2752.115
# 2  2010  2566.466              10812.547  26431.917        8762.006
# 3  2011  2787.925              12060.241  30568.400        9580.747
# 4  2012  2965.585              13005.288  32775.633        9018.800
# 5  2013  2926.666              13282.847  34242.067        9508.335
# 6  2014  2862.377              13261.812  35303.850        9532.100
# 7  2015  2414.585              12686.629  31892.400        7996.388
# 8  2016  2323.425              12748.265  32638.450        8134.929
# 9  2017  2528.996              13568.141  34655.867        8955.665
#
#    Middle East  North America  Northern Europe  South America  South Asia  \
# 0     7698.260       6178.296        23825.550       1925.238     461.375
# ...

# %%
df.set_index('Year', inplace=True)
df
# Out:
#       Africa  Australia and Oceanea  East Asia  Eastern Europe  Middle East  \
# Year
# 1990  24.794                 55.480     69.868          93.673       66.949
# 2000  35.794                 70.376     76.107          87.918       79.092
# 2010  49.247                 83.690     90.376          95.233       85.256
# 2011  48.263                 90.244     91.606          95.496       85.590
# 2012  49.690                 79.082     98.999          95.467       85.341
# 2013  53.448                108.945     97.719          97.549       87.344
# 2014  53.794                 97.587     98.157          97.256       94.976
# 2015  51.552                 95.747     97.392          97.158       97.659
# 2016  55.070                 89.476    100.867          97.732       92.528
# 2017  54.937                132.451    101.893          98.340       95.235
#
#       North America  Northern Europe  South America  South Asia  \
# Year
# ...

# %%
df2.set_index('Year', inplace=True)
df2
# Out:
#         Africa  Australia and Oceanea  East Asia  Eastern Europe  Middle East  \
# Year
# 1990  1074.953               5276.198   9369.982        2792.538     7698.260
# 2000  1123.489               5681.947  15563.327        2752.115    10924.707
# 2010  2566.466              10812.547  26431.917        8762.006    19843.487
# 2011  2787.925              12060.241  30568.400        9580.747    22937.507
# 2012  2965.585              13005.288  32775.633        9018.800    23529.727
# 2013  2926.666              13282.847  34242.067        9508.335    23593.687
# 2014  2862.377              13261.812  35303.850        9532.100    23160.160
# 2015  2414.585              12686.629  31892.400        7996.388    19152.727
# 2016  2323.425              12748.265  32638.450        8134.929    18550.907
# 2017  2528.996              13568.141  34655.867        8955.665    19636.960
#
#       North America  Northern Europe  South America  South Asia  \
# Year
# ...

# %%
x_label = df.index
x = np.arange(0,10,1)
y1 = df['Africa'][0:10]
y2 = df['Australia and Oceanea'][0:10]
y3 = df['East Asia'][0:10]
y4 = df['Eastern Europe'][0:10]
y6 = df['North America'][0:10]
y7 = df['Northern Europe'][0:10]
y8 = df['South America'][0:10]
y10 = df['Southeast Asia'][0:10]
y12 = df['Western Europe'][0:10]

# %%
fig = plt.figure(figsize=(16,9))

ax = fig.add_axes([0.1,0.1,0.8,0.8])

line1, = ax.plot(x, y1, label='Africa')
line1.set_linewidth(2)  

line2, = ax.plot(x, y2, label='Australia and Oceanea')   
line2.set_linewidth(2)  

line3, = ax.plot(x, y3, label='East Asia')   
line3.set_linewidth(2)  

line4, = ax.plot(x, y4, label='Eastern Europe') 
line4.set_linewidth(2)  

line6, = ax.plot(x, y6, label='North America')   
line6.set_linewidth(2)  

line7, = ax.plot(x, y7, label='Northern Europe')   
line7.set_linewidth(2)  

line8, = ax.plot(x, y8, label='South America') 
line8.set_linewidth(2)  

line10, = ax.plot(x, y10, label='Southeast Asia')   
line10.set_linewidth(2)  

line12, = ax.plot(x, y12, label='Western Europe') 
line12.set_linewidth(2)  

ax.set_xlabel('Year')
ax.set_ylabel('Percent gross')
ax.set_title('School enrollment, secondary between 1990-2017')

ax.set_ylim(0,150)

ax.set_xticks(x)
ax.set_xticklabels(x_label, rotation=45)

ax.legend()
            
fig.savefig('SchoolEnrollmentSecondary_line.jpg')

# %%
x_label = df2.index
x = np.arange(0,10,1)
y1 = df2['Africa'][0:10]
y2 = df2['Australia and Oceanea'][0:10]
y3 = df2['East Asia'][0:10]
y4 = df2['Eastern Europe'][0:10]
y5 = df2['Middle East'][0:10]
y6 = df2['North America'][0:10]
y7 = df2['Northern Europe'][0:10]
y8 = df2['South America'][0:10]
y9 = df2['South Asia'][0:10]
y10 = df2['Southeast Asia'][0:10]
y11 = df2['Western Asia'][0:10]
y12 = df2['Western Europe'][0:10]

# %%
fig = plt.figure(figsize=(16,9))

ax = fig.add_axes([0.1,0.1,0.8,0.8])

line1, = ax.plot(x, y1, label='Africa')
line1.set_linewidth(2)  

line2, = ax.plot(x, y2, label='Australia and Oceanea')   
line2.set_linewidth(2)  

line3, = ax.plot(x, y3, label='East Asia')   
line3.set_linewidth(2)  

line4, = ax.plot(x, y4, label='Eastern Europe') 
line4.set_linewidth(2)  

line5, = ax.plot(x, y5, label='Middle East')
line5.set_linewidth(2)  

line6, = ax.plot(x, y6, label='North America')   
line6.set_linewidth(2)  

line7, = ax.plot(x, y7, label='Northern Europe')   
line7.set_linewidth(2)  

line8, = ax.plot(x, y8, label='South America') 
line8.set_linewidth(2)  

line9, = ax.plot(x, y9, label='South Asia')
line9.set_linewidth(2)  

line10, = ax.plot(x, y10, label='Southeast Asia')   
line10.set_linewidth(2)  

line11, = ax.plot(x, y11, label='Western Asia')   
line11.set_linewidth(2)  

line12, = ax.plot(x, y12, label='Western Europe') 
line12.set_linewidth(2)  

ax.set_xlabel('Year')
ax.set_ylabel('GDP')
ax.set_title('GDP between 1990-2017')

ax.set_ylim(0,70000)

ax.set_xticks(x)
ax.set_xticklabels(x_label, rotation=45)

ax.legend()
            
fig.savefig('GDP_line.jpg')

# %%
trace1 = go.Scatter(x=df.index,
                    y=df['Africa'],
                    mode='lines+markers',
                    name='Africa')
trace2 = go.Scatter(x=df.index,
                    y=df['Australia and Oceanea'],
                    mode='lines+markers',
                    name='Australia and Oceanea')
trace3 = go.Scatter(x=df.index,
                    y=df['East Asia'],
                    mode='lines+markers',
                    name='East Asia')
trace4 = go.Scatter(x=df.index,
                    y=df['North America'],
                    mode='lines+markers',
                    name='North America')
trace5 = go.Scatter(x=df.index,
                    y=df['Northern Europe'],
                    mode='lines+markers',
                    name='Northern Europe')
trace6 = go.Scatter(x=df.index,
                    y=df['South America'],
                    mode='lines+markers',
                    name='South America')
trace7 = go.Scatter(x=df.index,
                    y=df['Southeast Asia'],
                    mode='lines+markers',
                    name='Southeast Asia')
trace8 = go.Scatter(x=df.index,
                    y=df['Western Europe'],
                    mode='lines+markers',
                    name='Western Europe')
data = [trace1, 
        trace2,
        trace3, 
        trace4,
        trace5, 
        trace6,
        trace7, 
        trace8]

# %%
layout = go.Layout(title='School enrollment, secondary between 1990-2017',
                   xaxis = {'title':'Year'},
                   yaxis = {'title':'Percent gross',
                           'range': [0,150]}, 
                   hovermode='closest',
                   )

# %%
fig = go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
trace1 = go.Scatter(x=df2.index,
                    y=df2['Africa'],
                    mode='lines+markers',
                    name='Africa')
trace2 = go.Scatter(x=df2.index,
                    y=df2['Australia and Oceanea'],
                    mode='lines+markers',
                    name='Australia and Oceanea')
trace3 = go.Scatter(x=df2.index,
                    y=df2['East Asia'],
                    mode='lines+markers',
                    name='East Asia')
trace4 = go.Scatter(x=df2.index,
                    y=df2['North America'],
                    mode='lines+markers',
                    name='North America')
trace5 = go.Scatter(x=df2.index,
                    y=df2['Northern Europe'],
                    mode='lines+markers',
                    name='Northern Europe')
trace6 = go.Scatter(x=df2.index,
                    y=df2['South America'],
                    mode='lines+markers',
                    name='South America')
trace7 = go.Scatter(x=df2.index,
                    y=df2['Southeast Asia'],
                    mode='lines+markers',
                    name='Southeast Asia')
trace8 = go.Scatter(x=df2.index,
                    y=df2['Western Europe'],
                    mode='lines+markers',
                    name='Western Europe')
data = [trace1, 
        trace2,
        trace3, 
        trace4,
        trace5, 
        trace6,
        trace7, 
        trace8]

# %%
layout = go.Layout(title='GDP between 1990-2017',
                   xaxis = {'title':'Year'},
                   yaxis = {'title':'GDP',
                           'range': [0,70000]}, 
                   hovermode='closest',
                   )

# %%
fig = go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
trace1 = go.Bar(x=df.index,
                    y=df['Africa'],
                    name='Africa')
trace2 = go.Bar(x=df.index,
                    y=df['Australia and Oceanea'],
                    name='Australia and Oceanea')
trace3 = go.Bar(x=df.index,
                    y=df['East Asia'],
                    name='East Asia')
trace4 = go.Bar(x=df.index,
                    y=df['North America'],
                    name='North America')
trace5 = go.Bar(x=df.index,
                    y=df['Northern Europe'],
                    name='Northern Europe')
trace6 = go.Bar(x=df.index,
                    y=df['South America'],
                    name='South America')
trace7 = go.Bar(x=df.index,
                    y=df['Southeast Asia'],
                    name='Southeast Asia')
trace8 = go.Bar(x=df.index,
                    y=df['Western Europe'],
                    name='Western Europe')
data = [trace1, 
        trace2,
        trace3, 
        trace4,
        trace5, 
        trace6,
        trace7, 
        trace8]

# %%
layout = go.Layout(title='School enrollment, secondary between 1990-2017',
                   xaxis = {'title':'year'},
                   yaxis = {'title':'Percent gross'}, 
                   hovermode='closest',
                   barmode='stack')
fig = go.Figure(data=data,layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
trace1 = go.Bar(x=df2.index,
                    y=df2['Africa'],
                    name='Africa')
trace2 = go.Bar(x=df2.index,
                    y=df2['Australia and Oceanea'],
                    name='Australia and Oceanea')
trace3 = go.Bar(x=df2.index,
                    y=df2['East Asia'],
                    name='East Asia')
trace4 = go.Bar(x=df2.index,
                    y=df2['North America'],
                    name='North America')
trace5 = go.Bar(x=df2.index,
                    y=df2['Northern Europe'],
                    name='Northern Europe')
trace6 = go.Bar(x=df2.index,
                    y=df2['South America'],
                    name='South America')
trace7 = go.Bar(x=df2.index,
                    y=df2['Southeast Asia'],
                    name='Southeast Asia')
trace8 = go.Bar(x=df2.index,
                    y=df2['Western Europe'],
                    name='Western Europe')
data = [trace1, 
        trace2,
        trace3, 
        trace4,
        trace5, 
        trace6,
        trace7, 
        trace8]

# %%
layout = go.Layout(title='GDP between 1990-2017',
                   xaxis = {'title':'year'},
                   yaxis = {'title':'GDP'}, 
                   hovermode='closest',
                   barmode='stack')
fig = go.Figure(data=data,layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
trace =go.Pie(labels=df2.columns,
              values=df2.iloc[0],
              hoverinfo='label+percent',
              textinfo='value'
             )
data = [trace]

# %%
layout = go.Layout(title='GDP in 1990')

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
trace =go.Pie(labels=df2.columns,
              values=df2.iloc[9],
              hoverinfo='label+percent',
              textinfo='value'
             )
data = [trace]

# %%
layout = go.Layout(title='GDP in 2017')

fig = go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
df3 = pd.read_csv('Secondary_Deviation.csv')
df3
# Out:
#    Year  Africa  Southeast Asia  Northern Europe
# 0  2010  13.454          17.485           -3.446
# 1  2011  -0.985           5.480           -0.415
# 2  2012   1.428           2.931            0.485
# 3  2013   3.758           0.910           13.036
# 4  2014   0.346          -1.471            0.315
# 5  2015  -2.242           5.614            1.351
# 6  2016   3.519           1.103            0.722
# 7  2017  -0.133           1.042            2.385

# %%
df3.set_index('Year', inplace=True)
df3
# Out:
#       Africa  Southeast Asia  Northern Europe
# Year
# 2010  13.454          17.485           -3.446
# 2011  -0.985           5.480           -0.415
# 2012   1.428           2.931            0.485
# 2013   3.758           0.910           13.036
# 2014   0.346          -1.471            0.315
# 2015  -2.242           5.614            1.351
# 2016   3.519           1.103            0.722
# 2017  -0.133           1.042            2.385

# %%
trace1 = go.Bar(x=df3.index,
                    y=df3['Africa'],
                    name='Africa')
trace2 = go.Bar(x=df3.index,
                    y=df3['Southeast Asia'],
                    name='Southeast Asia')
trace3 = go.Bar(x=df3.index,
                    y=df3['Northern Europe'],
                    name='Northern Europe')
data = [trace1, trace2, trace3]

# %%
layout = go.Layout(title='School enrollment,secondary (percent gross) compare to last year',
                   xaxis = {'title':'year'},
                   yaxis = {'title':'Percent gross'}, 
                   hovermode='closest')
fig = go.Figure(data=data,layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
df4 = pd.read_csv('GDP_Deviation.csv')
df4
# Out:
#    Year    Africa  Southeast Asia  Northern Europe
# 0  2010  1442.977        5524.026        22599.023
# 1  2011   221.458        2271.800         4682.800
# 2  2012   177.660         429.420        -1335.077
# 3  2013   -38.919        -185.840         2475.708
# 4  2014   -64.289        -308.040         2008.415
# 5  2015  -447.792       -1483.660        -5624.962
# 6  2016   -91.160        -283.730          980.123
# 7  2017   205.572         615.850         -875.502

# %%
df4.set_index('Year', inplace=True)
df4
# Out:
#         Africa  Southeast Asia  Northern Europe
# Year
# 2010  1442.977        5524.026        22599.023
# 2011   221.458        2271.800         4682.800
# 2012   177.660         429.420        -1335.077
# 2013   -38.919        -185.840         2475.708
# 2014   -64.289        -308.040         2008.415
# 2015  -447.792       -1483.660        -5624.962
# 2016   -91.160        -283.730          980.123
# 2017   205.572         615.850         -875.502

# %%
trace1 = go.Bar(x=df4.index,
                    y=df4['Africa'],
                    name='Africa')
trace2 = go.Bar(x=df4.index,
                    y=df4['Southeast Asia'],
                    name='Southeast Asia')
trace3 = go.Bar(x=df4.index,
                    y=df4['Northern Europe'],
                    name='Northern Europe')
data = [trace1, trace2, trace3]

# %%
layout = go.Layout(title='GDP compare to last year',
                   xaxis = {'title':'year'},
                   yaxis = {'title':'GDP'}, 
                   hovermode='closest')
fig = go.Figure(data=data,layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'
